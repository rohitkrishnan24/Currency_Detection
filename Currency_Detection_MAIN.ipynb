# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, BatchNormalization,Dropout,GlobalAveragePooling2D, MaxPooling1D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.applications import EfficientNetB0

import numpy as np
from glob import glob

# %%
batch = 32
img_height = 180
img_width = 180

#train_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Train'
#test_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Test'

#train_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Laplacian/Train'
#test_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Laplacian/Test'

train_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Gaussian/Train'
test_path = 'C:/Users/rohit/OneDrive/Documents/IP J comp/Gaussian/Test'

# %%
import PIL, pathlib
train_path = pathlib.Path(train_path)
onehundred = list(train_path.glob('1Hundrednote/*'))
PIL.Image.open(str(onehundred[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x152>

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
                train_path,
  seed=123,color_mode='rgb',
  image_size=(img_height, img_width),
  batch_size=batch)
print(train_ds)
# Out:
# Found 153 files belonging to 7 classes.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
#  validation_split=0.1,
 # subset="validation",
  seed=123,color_mode='rgb',
  image_size=(img_height, img_width),
  batch_size=batch)
# Out:
# Found 42 files belonging to 7 classes.

# %%
class_names = train_ds.class_names
print(train_ds)
print(class_names)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# ['1Hundrednote', '2Hundrednote', '2Thousandnote', '5Hundrednote', 'Fiftynote', 'Tennote', 'Twentynote']

# %%
#Data Visualization
import cv2
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    #laplacian=cv2.Laplacian(images[i].numpy().astype("uint8"),cv2.CV_64F)
    #plt.imshow(laplacian)
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#normalize data by using a rescaling layer

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
Classifier=Sequential()

Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
Classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 59168)             0
#
#  dense_6 (Dense)             (None, 128)               7573632
#
#  dense_7 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,584,679
# Trainable params: 7,584,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
from PIL import _imaging
from PIL import Image
#fit the classifier
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/30
# 5/5 [==============================] - 3s 590ms/step - loss: 6.7403 - accuracy: 0.0588 - val_loss: 2.1023 - val_accuracy: 0.1429
# Epoch 2/30
# 5/5 [==============================] - 2s 487ms/step - loss: 2.0377 - accuracy: 0.1503 - val_loss: 1.9525 - val_accuracy: 0.2619
# Epoch 3/30
# 5/5 [==============================] - 2s 467ms/step - loss: 1.8931 - accuracy: 0.2484 - val_loss: 1.8937 - val_accuracy: 0.2143
# Epoch 4/30
# 5/5 [==============================] - 2s 466ms/step - loss: 1.7649 - accuracy: 0.3922 - val_loss: 1.7854 - val_accuracy: 0.3095
# Epoch 5/30
# 5/5 [==============================] - 2s 457ms/step - loss: 1.6088 - accuracy: 0.4118 - val_loss: 1.6975 - val_accuracy: 0.3333
# Epoch 6/30
# 5/5 [==============================] - 2s 454ms/step - loss: 1.3969 - accuracy: 0.5686 - val_loss: 1.5587 - val_accuracy: 0.3571
# Epoch 7/30
# 5/5 [==============================] - 2s 459ms/step - loss: 1.1638 - accuracy: 0.6340 - val_loss: 1.4202 - val_accuracy: 0.4762
# Epoch 8/30
# 5/5 [==============================] - 2s 457ms/step - loss: 0.8686 - accuracy: 0.7908 - val_loss: 1.1433 - val_accuracy: 0.5476
# Epoch 9/30
# 5/5 [==============================] - 2s 467ms/step - loss: 0.6135 - accuracy: 0.8693 - val_loss: 1.0128 - val_accuracy: 0.6429
# Epoch 10/30
# 5/5 [==============================] - 2s 460ms/step - loss: 0.4484 - accuracy: 0.8954 - val_loss: 1.0381 - val_accuracy: 0.6190
# Epoch 11/30
# 5/5 [==============================] - 2s 469ms/step - loss: 0.3053 - accuracy: 0.9281 - val_loss: 1.2446 - val_accuracy: 0.5000
# Epoch 12/30
# 5/5 [==============================] - 2s 457ms/step - loss: 0.2114 - accuracy: 0.9673 - val_loss: 0.8796 - val_accuracy: 0.6905
# Epoch 13/30
# 5/5 [==============================] - 2s 453ms/step - loss: 0.1463 - accuracy: 0.9739 - val_loss: 1.2631 - val_accuracy: 0.6667
# Epoch 14/30
# 5/5 [==============================] - 2s 456ms/step - loss: 0.1894 - accuracy: 0.9477 - val_loss: 0.9041 - val_accuracy: 0.7143
# Epoch 15/30
# 5/5 [==============================] - 2s 465ms/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 1.0995 - val_accuracy: 0.6667
# Epoch 16/30
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0554 - accuracy: 0.9935 - val_loss: 0.9172 - val_accuracy: 0.6905
# Epoch 17/30
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0367 - accuracy: 0.9935 - val_loss: 0.9277 - val_accuracy: 0.6905
# Epoch 18/30
# 5/5 [==============================] - 3s 549ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 1.1074 - val_accuracy: 0.7381
# Epoch 19/30
# 5/5 [==============================] - 3s 548ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 1.1059 - val_accuracy: 0.7381
# Epoch 20/30
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0444 - val_accuracy: 0.7381
# Epoch 21/30
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.0319 - val_accuracy: 0.6905
# Epoch 22/30
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0671 - val_accuracy: 0.7381
# Epoch 23/30
# 5/5 [==============================] - 3s 495ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.1007 - val_accuracy: 0.7619
# Epoch 24/30
# 5/5 [==============================] - 2s 510ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0673 - val_accuracy: 0.7143
# Epoch 25/30
# 5/5 [==============================] - 2s 490ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0542 - val_accuracy: 0.7381
# Epoch 26/30
# 5/5 [==============================] - 2s 475ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0448 - val_accuracy: 0.7381
# Epoch 27/30
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.7381
# Epoch 28/30
# 5/5 [==============================] - 2s 485ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0785 - val_accuracy: 0.7381
# Epoch 29/30
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0727 - val_accuracy: 0.7381
# Epoch 30/30
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0709 - val_accuracy: 0.7381

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
# Out:
# mean_test_accuracy:  0.6023809512456259

# %%
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.827450983847181

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Data Augmentation to reduce overfitting

data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
Classifier=Sequential()

Classifier.add(data_augmentation)
Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))
Classifier.add(layers.Dropout(0.2))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
Classifier.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
Classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 43, 43, 32)        0
#
#  flatten (Flatten)           (None, 59168)             0
#
#  dense (Dense)               (None, 128)               7573632
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,584,679
# Trainable params: 7,584,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# C:\Users\athul\AppData\Roaming\Python\Python310\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 5/5 [==============================] - 7s 814ms/step - loss: 3.1922 - accuracy: 0.1699 - val_loss: 2.1308 - val_accuracy: 0.1667
# Epoch 2/30
# 5/5 [==============================] - 4s 836ms/step - loss: 1.9397 - accuracy: 0.2157 - val_loss: 1.7699 - val_accuracy: 0.3571
# Epoch 3/30
# 5/5 [==============================] - 3s 616ms/step - loss: 1.6399 - accuracy: 0.3922 - val_loss: 1.3690 - val_accuracy: 0.4048
# Epoch 4/30
# 5/5 [==============================] - 3s 617ms/step - loss: 1.3326 - accuracy: 0.4575 - val_loss: 1.1072 - val_accuracy: 0.5714
# Epoch 5/30
# 5/5 [==============================] - 3s 551ms/step - loss: 1.1711 - accuracy: 0.5425 - val_loss: 1.0487 - val_accuracy: 0.6190
# Epoch 6/30
# 5/5 [==============================] - 3s 554ms/step - loss: 1.0144 - accuracy: 0.6209 - val_loss: 0.9520 - val_accuracy: 0.5952
# Epoch 7/30
# 5/5 [==============================] - 3s 553ms/step - loss: 0.8695 - accuracy: 0.7190 - val_loss: 0.8075 - val_accuracy: 0.6429
# Epoch 8/30
# 5/5 [==============================] - 3s 659ms/step - loss: 0.7884 - accuracy: 0.7320 - val_loss: 0.7345 - val_accuracy: 0.6667
# Epoch 9/30
# 5/5 [==============================] - 3s 632ms/step - loss: 0.6682 - accuracy: 0.8039 - val_loss: 0.7771 - val_accuracy: 0.6667
# Epoch 10/30
# 5/5 [==============================] - 3s 588ms/step - loss: 0.5885 - accuracy: 0.8105 - val_loss: 0.9092 - val_accuracy: 0.6905
# Epoch 11/30
# 5/5 [==============================] - 3s 626ms/step - loss: 0.5354 - accuracy: 0.8431 - val_loss: 0.6035 - val_accuracy: 0.7619
# Epoch 12/30
# 5/5 [==============================] - 3s 631ms/step - loss: 0.4973 - accuracy: 0.8170 - val_loss: 0.6014 - val_accuracy: 0.7857
# Epoch 13/30
# 5/5 [==============================] - 3s 600ms/step - loss: 0.4029 - accuracy: 0.8693 - val_loss: 0.5230 - val_accuracy: 0.7857
# Epoch 14/30
# 5/5 [==============================] - 3s 583ms/step - loss: 0.3222 - accuracy: 0.9150 - val_loss: 0.6238 - val_accuracy: 0.7381
# Epoch 15/30
# 5/5 [==============================] - 3s 626ms/step - loss: 0.2451 - accuracy: 0.9346 - val_loss: 0.6748 - val_accuracy: 0.7857
# Epoch 16/30
# 5/5 [==============================] - 3s 615ms/step - loss: 0.2893 - accuracy: 0.8954 - val_loss: 0.4341 - val_accuracy: 0.7857
# Epoch 17/30
# 5/5 [==============================] - 3s 613ms/step - loss: 0.2259 - accuracy: 0.9150 - val_loss: 0.5718 - val_accuracy: 0.7619
# Epoch 18/30
# 5/5 [==============================] - 3s 622ms/step - loss: 0.1958 - accuracy: 0.9412 - val_loss: 0.4172 - val_accuracy: 0.8810
# Epoch 19/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.1961 - accuracy: 0.9477 - val_loss: 0.5482 - val_accuracy: 0.7857
# Epoch 20/30
# 5/5 [==============================] - 3s 628ms/step - loss: 0.2179 - accuracy: 0.9216 - val_loss: 0.4210 - val_accuracy: 0.8095
# Epoch 21/30
# 5/5 [==============================] - 3s 599ms/step - loss: 0.1924 - accuracy: 0.9346 - val_loss: 0.6043 - val_accuracy: 0.8095
# Epoch 22/30
# 5/5 [==============================] - 3s 609ms/step - loss: 0.1315 - accuracy: 0.9739 - val_loss: 0.4469 - val_accuracy: 0.7619
# Epoch 23/30
# 5/5 [==============================] - 3s 599ms/step - loss: 0.1388 - accuracy: 0.9542 - val_loss: 0.5990 - val_accuracy: 0.7857
# Epoch 24/30
# 5/5 [==============================] - 3s 584ms/step - loss: 0.1157 - accuracy: 0.9477 - val_loss: 0.5208 - val_accuracy: 0.7857
# Epoch 25/30
# 5/5 [==============================] - 3s 608ms/step - loss: 0.1212 - accuracy: 0.9673 - val_loss: 0.6651 - val_accuracy: 0.7857
# Epoch 26/30
# 5/5 [==============================] - 3s 587ms/step - loss: 0.0838 - accuracy: 0.9869 - val_loss: 0.4992 - val_accuracy: 0.8095
# Epoch 27/30
# 5/5 [==============================] - 3s 598ms/step - loss: 0.0783 - accuracy: 0.9804 - val_loss: 0.5322 - val_accuracy: 0.8095
# Epoch 28/30
# 5/5 [==============================] - 3s 593ms/step - loss: 0.0704 - accuracy: 0.9869 - val_loss: 0.5370 - val_accuracy: 0.8810
# Epoch 29/30
# 5/5 [==============================] - 3s 615ms/step - loss: 0.0636 - accuracy: 0.9935 - val_loss: 0.5161 - val_accuracy: 0.8333
# Epoch 30/30
# 5/5 [==============================] - 3s 618ms/step - loss: 0.0425 - accuracy: 0.9935 - val_loss: 0.4801 - val_accuracy: 0.8095

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
print('\n')
# Out:
# mean_test_accuracy:  0.7111111099521319

# %%
mean_train = (max(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.9934640526771545

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(180,180,3))

Classifier=Sequential()

Classifier.add(effnet)

Classifier.add(GlobalAveragePooling2D())

Classifier.add(Flatten())

Classifier.add(Dense(512,activation='relu'))
Classifier.add(Dense(128,activation='relu'))

Classifier.add(Dense(64,activation='relu'))
Classifier.add(Dense(32,activation='relu'))

Classifier.add(Dropout(0.3))

Classifier.add(Dense(units = 32, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
Classifier.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 6, 6, 1280)       4049571
#
#  global_average_pooling2d_2   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  flatten_3 (Flatten)         (None, 1280)              0
#
#  dense_14 (Dense)            (None, 512)               655872
#
#  dense_15 (Dense)            (None, 128)               65664
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 32)                2080
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_18 (Dense)            (None, 32)                1056
#
#  dense_19 (Dense)            (None, 7)                 231
#
# =================================================================
# Total params: 4,782,730
# Trainable params: 4,740,707
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
from PIL import _imaging
from PIL import Image
#fit the classifier
epochs = 25
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 18s 4s/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 4.2376 - val_accuracy: 0.7381
# Epoch 2/25
# 5/5 [==============================] - 17s 4s/step - loss: 0.0661 - accuracy: 0.9869 - val_loss: 3.7506 - val_accuracy: 0.7619
# Epoch 3/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0861 - accuracy: 0.9869 - val_loss: 2.5986 - val_accuracy: 0.7381
# Epoch 4/25
# 5/5 [==============================] - 19s 4s/step - loss: 0.1568 - accuracy: 0.9739 - val_loss: 1.6493 - val_accuracy: 0.7381
# Epoch 5/25
# 5/5 [==============================] - 17s 3s/step - loss: 0.3433 - accuracy: 0.9739 - val_loss: 4.3670 - val_accuracy: 0.6667
# Epoch 6/25
# 5/5 [==============================] - 18s 4s/step - loss: 0.2114 - accuracy: 0.9542 - val_loss: 2.2462 - val_accuracy: 0.6905
# Epoch 7/25
# 5/5 [==============================] - 18s 4s/step - loss: 0.2331 - accuracy: 0.9412 - val_loss: 2.1271 - val_accuracy: 0.6905
# Epoch 8/25
# 5/5 [==============================] - 19s 4s/step - loss: 0.2733 - accuracy: 0.9346 - val_loss: 1.9188 - val_accuracy: 0.6905
# Epoch 9/25
# 5/5 [==============================] - 19s 4s/step - loss: 0.2196 - accuracy: 0.9542 - val_loss: 1.0307 - val_accuracy: 0.7381
# Epoch 10/25
# 5/5 [==============================] - 19s 4s/step - loss: 0.0697 - accuracy: 0.9804 - val_loss: 2.3963 - val_accuracy: 0.6905
# Epoch 11/25
# 5/5 [==============================] - 18s 4s/step - loss: 0.2533 - accuracy: 0.9542 - val_loss: 6.7980 - val_accuracy: 0.5952
# Epoch 12/25
# 5/5 [==============================] - 18s 4s/step - loss: 0.1717 - accuracy: 0.9673 - val_loss: 5.4709 - val_accuracy: 0.5714
# Epoch 13/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 4.7929 - val_accuracy: 0.6190
# Epoch 14/25
# 5/5 [==============================] - 17s 3s/step - loss: 0.0711 - accuracy: 0.9739 - val_loss: 2.5296 - val_accuracy: 0.8571
# Epoch 15/25
# 5/5 [==============================] - 20s 4s/step - loss: 0.0794 - accuracy: 0.9739 - val_loss: 2.0085 - val_accuracy: 0.8810
# Epoch 16/25
# 5/5 [==============================] - 21s 4s/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 1.1328 - val_accuracy: 0.9286
# Epoch 17/25
# 5/5 [==============================] - 24s 5s/step - loss: 0.0315 - accuracy: 0.9935 - val_loss: 0.8621 - val_accuracy: 0.9524
# Epoch 18/25
# 5/5 [==============================] - 25s 5s/step - loss: 0.0233 - accuracy: 0.9869 - val_loss: 0.6521 - val_accuracy: 0.9524
# Epoch 19/25
# 5/5 [==============================] - 24s 5s/step - loss: 0.0357 - accuracy: 0.9804 - val_loss: 0.6759 - val_accuracy: 0.9048
# Epoch 20/25
# 5/5 [==============================] - 1941s 484s/step - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.7141 - val_accuracy: 0.9048
# Epoch 21/25
# 5/5 [==============================] - 19s 4s/step - loss: 0.0382 - accuracy: 0.9935 - val_loss: 0.6519 - val_accuracy: 0.9048
# Epoch 22/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0173 - accuracy: 0.9935 - val_loss: 0.5832 - val_accuracy: 0.9286
# Epoch 23/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.9286
# Epoch 24/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0243 - accuracy: 0.9935 - val_loss: 0.3764 - val_accuracy: 0.9762
# Epoch 25/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0153 - accuracy: 0.9869 - val_loss: 0.3408 - val_accuracy: 0.9762

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
# Out:
# mean_test_accuracy:  0.8009523749351501

# %%
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.9790849685668945

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Use classifier to run prediction on any new image

from tensorflow.keras.preprocessing import image
img = image.load_img('C:/Users/athul/OneDrive/Documents/IP J comp/PI/4.jpg',
                       target_size=(img_height,img_width))
img=cv2.GaussianBlur(np.array(img),(3,3),cv2.BORDER_DEFAULT)
plt.imshow(img)

# %%
test_image=image.img_to_array(img)
test_image=np.expand_dims(test_image, axis = 0)

result =np.argmax(Classifier.predict(test_image), axis=1)
result
# Out:
# 1/1 [==============================] - 0s 61ms/step
# array([0], dtype=int64)

# %%
prediction = class_names[result[0]]
prediction
# Out:
# '1Hundrednote'
