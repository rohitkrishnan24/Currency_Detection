# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
TRAIN_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Train'
TEST_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Test'
LAP_TRAIN_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Laplacian/Train'
LAP_TEST_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Laplacian/Test'
G_TRAIN_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Gaussian/Train'
G_TEST_DIR='C:/Users/rohit/OneDrive/Documents/IP J comp/Gaussian/Test'

# %%
classes=['1Hundrednote', '2Hundrednote', '2Thousandnote', '5Hundrednote', 'Fiftynote', 'Tennote', 'Twentynote']

# %%
train_ds=[]
for category in os.listdir(TRAIN_DIR):
    class_num=classes.index(category)
    new_path=TRAIN_DIR+"/"+category
    for img in os.listdir(new_path):
        img_array=cv2.imread(new_path+"/"+img,cv2.IMREAD_COLOR)
        gaus=cv2.GaussianBlur(img_array,(3,3),cv2.BORDER_DEFAULT)
        if(not os.path.exists(G_TRAIN_DIR+"/"+category)):
            os.mkdir(G_TRAIN_DIR+"/"+category)
        cv2.imwrite(G_TRAIN_DIR+"/"+category+"/"+img,gaus)
        plt.imshow(gaus)
# Out:
# C:\Users\athul\AppData\Local\Temp\ipykernel_19468\2216596250.py:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_ds=np.array(train_ds)
# (180, 180, 3)

# %%
test_ds=[]
for category in os.listdir(TEST_DIR):
    class_num=classes.index(category)
    new_path=TEST_DIR+"/"+category
    for img in os.listdir(new_path):
        img_array=cv2.imread(new_path+"/"+img,cv2.IMREAD_COLOR)
        gaus=cv2.GaussianBlur(img_array,(5,5),cv2.BORDER_DEFAULT)
        if(not os.path.exists(G_TEST_DIR+"/"+category)):
            os.mkdir(G_TEST_DIR+"/"+category)
        cv2.imwrite(G_TEST_DIR+"/"+category+"/"+img,gaus)
        plt.imshow(gaus)
        laplacian.resize(180,180,3)
# Out:
# C:\Users\athul\AppData\Local\Temp\ipykernel_19468\1129919859.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_ds=np.array(test_ds)
# (180, 180, 3)
